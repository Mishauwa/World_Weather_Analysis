# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities

cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City" : city.title(),
                          "Lat" : city_lat,
                          "Lng": city_lng,
                          "Max Temp" : city_max_temp,
                          "Humidity" : city_humidity,
                          "Cloudiness" : city_clouds,
                          "Wind Speed" : city_wind,
                          "Country" : city_country,
                          "Current description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | saint-philippe
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | liku
# Processing Record 7 of Set 1 | mbandaka
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | tilichiki
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | bandarbeyla
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | kumano
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | rocha
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | adrar
# Processing Record 20 of Set 1 | lavrentiya
# Processing Record 21 of Set 1 | paita
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | tete
# Processing Record 24 of Set 1 | ostrovnoy
# Processing Record 25 of Set 1 | coquimbo
# Processing Record 26 of Set 1 | victor harbor
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | richards bay
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | nikolskoye
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | caravelas
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | labuan
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | huangpi
# Processing Record 37 of Set 1 | yanchukan
# City not found. Skipping...
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | oksfjord
# Processing Record 41 of Set 1 | taitung
# Processing Record 42 of Set 1 | ust-nera
# Processing Record 43 of Set 1 | tambopata
# Processing Record 44 of Set 1 | korla
# Processing Record 45 of Set 1 | taltal
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 1 | isangel
# Processing Record 49 of Set 1 | grindavik
# Processing Record 50 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 2 | ancud
# Processing Record 2 of Set 2 | ippy
# Processing Record 3 of Set 2 | alekseyevsk
# Processing Record 4 of Set 2 | puerto ayacucho
# Processing Record 5 of Set 2 | pangnirtung
# Processing Record 6 of Set 2 | pacific grove
# Processing Record 7 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 2 | sangmelima
# Processing Record 9 of Set 2 | mahibadhoo
# Processing Record 10 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 2 | kapaa
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | pokhara
# Processing Record 14 of Set 2 | shelburne
# Processing Record 15 of Set 2 | necochea
# Processing Record 16 of Set 2 | nuuk
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | severo-kurilsk
# Processing Record 19 of Set 2 | huilong
# Processing Record 20 of Set 2 | palauig
# Processing Record 21 of Set 2 | newport
# Processing Record 22 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 2 | anadyr
# Processing Record 24 of Set 2 | luang prabang
# Processing Record 25 of Set 2 | bathsheba
# Processing Record 26 of Set 2 | beyneu
# Processing Record 27 of Set 2 | santa rosa
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | santa maria
# Processing Record 30 of Set 2 | ahipara
# Processing Record 31 of Set 2 | sola
# Processing Record 32 of Set 2 | klaksvik
# Processing Record 33 of Set 2 | cabo san lucas
# Processing Record 34 of Set 2 | albany
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | hermanus
# Processing Record 37 of Set 2 | tuktoyaktuk
# Processing Record 38 of Set 2 | sitka
# Processing Record 39 of Set 2 | shaowu
# Processing Record 40 of Set 2 | forestville
# Processing Record 41 of Set 2 | borama
# City not found. Skipping...
# Processing Record 42 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | fortuna
# Processing Record 45 of Set 2 | porto novo
# Processing Record 46 of Set 2 | luderitz
# Processing Record 47 of Set 2 | ambilobe
# Processing Record 48 of Set 2 | la libertad
# Processing Record 49 of Set 2 | yellowknife
# Processing Record 50 of Set 2 | resistencia
# Processing Record 1 of Set 3 | hamilton
# Processing Record 2 of Set 3 | namatanai
# Processing Record 3 of Set 3 | semey
# Processing Record 4 of Set 3 | berga
# Processing Record 5 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | aswan
# Processing Record 8 of Set 3 | chulym
# Processing Record 9 of Set 3 | copiapo
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | busselton
# Processing Record 14 of Set 3 | alofi
# Processing Record 15 of Set 3 | cap malheureux
# Processing Record 16 of Set 3 | kasongo-lunda
# Processing Record 17 of Set 3 | aksu
# Processing Record 18 of Set 3 | salekhard
# Processing Record 19 of Set 3 | progreso
# Processing Record 20 of Set 3 | esperance
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | vagur
# Processing Record 23 of Set 3 | pedro ii
# Processing Record 24 of Set 3 | sao miguel dos campos
# Processing Record 25 of Set 3 | labuhan
# Processing Record 26 of Set 3 | volnovakha
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | sibolga
# Processing Record 29 of Set 3 | koungheul
# Processing Record 30 of Set 3 | primero de marzo
# Processing Record 31 of Set 3 | iqaluit
# Processing Record 32 of Set 3 | honiara
# Processing Record 33 of Set 3 | coos bay
# Processing Record 34 of Set 3 | clyde river
# Processing Record 35 of Set 3 | vrangel
# Processing Record 36 of Set 3 | maues
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | norman wells
# Processing Record 39 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | nhulunbuy
# Processing Record 42 of Set 3 | evensk
# Processing Record 43 of Set 3 | san policarpo
# Processing Record 44 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 3 | hervey bay
# Processing Record 46 of Set 3 | rybinsk
# Processing Record 47 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 48 of Set 3 | avarua
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | de aar
# Processing Record 1 of Set 4 | riyadh
# Processing Record 2 of Set 4 | santarem
# Processing Record 3 of Set 4 | oistins
# Processing Record 4 of Set 4 | sorong
# Processing Record 5 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 4 | luzino
# Processing Record 7 of Set 4 | verkhnevilyuysk
# Processing Record 8 of Set 4 | port elizabeth
# Processing Record 9 of Set 4 | saint combs
# City not found. Skipping...
# Processing Record 10 of Set 4 | nikolskiy
# Processing Record 11 of Set 4 | ullapool
# Processing Record 12 of Set 4 | leesburg
# Processing Record 13 of Set 4 | puerto ayora
# Processing Record 14 of Set 4 | tiksi
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | payo
# Processing Record 17 of Set 4 | camabatela
# Processing Record 18 of Set 4 | juarez
# Processing Record 19 of Set 4 | san quintin
# Processing Record 20 of Set 4 | burica
# City not found. Skipping...
# Processing Record 21 of Set 4 | helsinki
# Processing Record 22 of Set 4 | punta alta
# Processing Record 23 of Set 4 | kozyatyn
# Processing Record 24 of Set 4 | praia da vitoria
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | tasiilaq
# Processing Record 27 of Set 4 | moffat
# Processing Record 28 of Set 4 | bluff
# Processing Record 29 of Set 4 | kegayli
# City not found. Skipping...
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | hithadhoo
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | sosnogorsk
# Processing Record 34 of Set 4 | roros
# Processing Record 35 of Set 4 | sale
# Processing Record 36 of Set 4 | lodja
# Processing Record 37 of Set 4 | tateyama
# Processing Record 38 of Set 4 | new norfolk
# Processing Record 39 of Set 4 | ilulissat
# Processing Record 40 of Set 4 | balikpapan
# Processing Record 41 of Set 4 | vao
# Processing Record 42 of Set 4 | rach gia
# Processing Record 43 of Set 4 | ojinaga
# Processing Record 44 of Set 4 | baykit
# Processing Record 45 of Set 4 | nome
# Processing Record 46 of Set 4 | suao
# City not found. Skipping...
# Processing Record 47 of Set 4 | neftcala
# Processing Record 48 of Set 4 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 4 | trincomalee
# Processing Record 50 of Set 4 | kholodnyy
# Processing Record 1 of Set 5 | moose factory
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | taldan
# Processing Record 4 of Set 5 | sierre
# Processing Record 5 of Set 5 | huarmey
# Processing Record 6 of Set 5 | maldonado
# Processing Record 7 of Set 5 | hobyo
# Processing Record 8 of Set 5 | kayerkan
# Processing Record 9 of Set 5 | te anau
# Processing Record 10 of Set 5 | christchurch
# Processing Record 11 of Set 5 | xuddur
# Processing Record 12 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 13 of Set 5 | bilma
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | oussouye
# Processing Record 16 of Set 5 | badnawar
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | acapulco
# Processing Record 19 of Set 5 | peachland
# Processing Record 20 of Set 5 | kahului
# Processing Record 21 of Set 5 | port washington
# Processing Record 22 of Set 5 | arenapolis
# Processing Record 23 of Set 5 | mount isa
# Processing Record 24 of Set 5 | mnogovershinnyy
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | lasem
# Processing Record 27 of Set 5 | kamenka
# Processing Record 28 of Set 5 | leningradskiy
# Processing Record 29 of Set 5 | comodoro rivadavia
# Processing Record 30 of Set 5 | muros
# Processing Record 31 of Set 5 | longyearbyen
# Processing Record 32 of Set 5 | miles city
# Processing Record 33 of Set 5 | calama
# Processing Record 34 of Set 5 | campbell river
# Processing Record 35 of Set 5 | yulara
# Processing Record 36 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | noyabrsk
# Processing Record 39 of Set 5 | villaviciosa
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | hambantota
# Processing Record 42 of Set 5 | coahuayana
# Processing Record 43 of Set 5 | talnakh
# Processing Record 44 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 45 of Set 5 | atar
# Processing Record 46 of Set 5 | yar-sale
# Processing Record 47 of Set 5 | kempsey
# Processing Record 48 of Set 5 | lebu
# Processing Record 49 of Set 5 | dunedin
# Processing Record 50 of Set 5 | ixtapa
# Processing Record 1 of Set 6 | saint-francois
# Processing Record 2 of Set 6 | ornskoldsvik
# Processing Record 3 of Set 6 | satipo
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | saint george
# Processing Record 6 of Set 6 | ucluelet
# Processing Record 7 of Set 6 | babu
# Processing Record 8 of Set 6 | olinda
# Processing Record 9 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 10 of Set 6 | corinth
# Processing Record 11 of Set 6 | aden
# Processing Record 12 of Set 6 | dikson
# Processing Record 13 of Set 6 | lata
# Processing Record 14 of Set 6 | plouzane
# Processing Record 15 of Set 6 | dagana
# Processing Record 16 of Set 6 | mount gambier
# Processing Record 17 of Set 6 | ketchikan
# Processing Record 18 of Set 6 | tevriz
# Processing Record 19 of Set 6 | sambava
# Processing Record 20 of Set 6 | haines junction
# Processing Record 21 of Set 6 | cah ab
# City not found. Skipping...
# Processing Record 22 of Set 6 | akyab
# Processing Record 23 of Set 6 | pangody
# Processing Record 24 of Set 6 | phalodi
# Processing Record 25 of Set 6 | vanino
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | yueyang
# Processing Record 28 of Set 6 | pemangkat
# Processing Record 29 of Set 6 | torbay
# Processing Record 30 of Set 6 | buenos aires
# Processing Record 31 of Set 6 | bethel
# Processing Record 32 of Set 6 | bahia honda
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | ascension
# Processing Record 35 of Set 6 | tiarei
# Processing Record 36 of Set 6 | svetlyy
# Processing Record 37 of Set 6 | alugan
# Processing Record 38 of Set 6 | talusan
# Processing Record 39 of Set 6 | tahe
# Processing Record 40 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 41 of Set 6 | dongsheng
# Processing Record 42 of Set 6 | kleck
# City not found. Skipping...
# Processing Record 43 of Set 6 | kruisfontein
# Processing Record 44 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 45 of Set 6 | bowen
# Processing Record 46 of Set 6 | entre rios
# Processing Record 47 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 6 | abnub
# Processing Record 49 of Set 6 | gimli
# Processing Record 50 of Set 6 | beachwood
# Processing Record 1 of Set 7 | san patricio
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | mae hong son
# Processing Record 4 of Set 7 | kyabram
# Processing Record 5 of Set 7 | jega
# Processing Record 6 of Set 7 | kropotkin
# Processing Record 7 of Set 7 | henties bay
# Processing Record 8 of Set 7 | hasaki
# Processing Record 9 of Set 7 | takefu
# Processing Record 10 of Set 7 | komsomolskiy
# Processing Record 11 of Set 7 | semnan
# Processing Record 12 of Set 7 | dalvik
# Processing Record 13 of Set 7 | leh
# Processing Record 14 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 7 | kargapolye
# City not found. Skipping...
# Processing Record 16 of Set 7 | almaznyy
# Processing Record 17 of Set 7 | salinas
# Processing Record 18 of Set 7 | kyra
# Processing Record 19 of Set 7 | koumac
# Processing Record 20 of Set 7 | key west
# Processing Record 21 of Set 7 | provideniya
# Processing Record 22 of Set 7 | nenjiang
# Processing Record 23 of Set 7 | barbacoas
# Processing Record 24 of Set 7 | orotina
# Processing Record 25 of Set 7 | port hardy
# Processing Record 26 of Set 7 | port-cartier
# Processing Record 27 of Set 7 | alakurtti
# Processing Record 28 of Set 7 | barra do garcas
# Processing Record 29 of Set 7 | ilhabela
# Processing Record 30 of Set 7 | simao
# Processing Record 31 of Set 7 | merauke
# Processing Record 32 of Set 7 | igrim
# Processing Record 33 of Set 7 | russell
# Processing Record 34 of Set 7 | padang
# Processing Record 35 of Set 7 | marienburg
# Processing Record 36 of Set 7 | siukh
# Processing Record 37 of Set 7 | corinto
# Processing Record 38 of Set 7 | gandu
# Processing Record 39 of Set 7 | tabou
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | santa fe
# Processing Record 42 of Set 7 | honningsvag
# Processing Record 43 of Set 7 | east london
# Processing Record 44 of Set 7 | santa branca
# Processing Record 45 of Set 7 | kloulklubed
# Processing Record 46 of Set 7 | singaraja
# Processing Record 47 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 7 | manhumirim
# Processing Record 49 of Set 7 | camacha
# Processing Record 50 of Set 7 | novobiryusinskiy
# Processing Record 1 of Set 8 | montepuez
# Processing Record 2 of Set 8 | chester
# Processing Record 3 of Set 8 | souillac
# Processing Record 4 of Set 8 | paamiut
# Processing Record 5 of Set 8 | aklavik
# Processing Record 6 of Set 8 | hailar
# Processing Record 7 of Set 8 | sobolevo
# Processing Record 8 of Set 8 | tuatapere
# Processing Record 9 of Set 8 | suntar
# Processing Record 10 of Set 8 | shwebo
# Processing Record 11 of Set 8 | cidreira
# Processing Record 12 of Set 8 | vila franca do campo
# Processing Record 13 of Set 8 | santa vitoria do palmar
# Processing Record 14 of Set 8 | naze
# Processing Record 15 of Set 8 | grand forks
# Processing Record 16 of Set 8 | faya
# Processing Record 17 of Set 8 | voi
# Processing Record 18 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 8 | quang ngai
# Processing Record 20 of Set 8 | kichera
# Processing Record 21 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 8 | los llanos de aridane
# Processing Record 23 of Set 8 | tucuman
# Processing Record 24 of Set 8 | kaputa
# Processing Record 25 of Set 8 | leander
# Processing Record 26 of Set 8 | agdas
# Processing Record 27 of Set 8 | majene
# Processing Record 28 of Set 8 | sao filipe
# Processing Record 29 of Set 8 | havre-saint-pierre
# Processing Record 30 of Set 8 | yusva
# City not found. Skipping...
# Processing Record 31 of Set 8 | bilibino
# Processing Record 32 of Set 8 | zaltan
# Processing Record 33 of Set 8 | hede
# Processing Record 34 of Set 8 | la union
# Processing Record 35 of Set 8 | moron
# Processing Record 36 of Set 8 | ngunguru
# Processing Record 37 of Set 8 | omsukchan
# Processing Record 38 of Set 8 | adre
# Processing Record 39 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 8 | formosa
# Processing Record 41 of Set 8 | katsuura
# Processing Record 42 of Set 8 | quesnel
# Processing Record 43 of Set 8 | bambanglipuro
# Processing Record 44 of Set 8 | pochutla
# Processing Record 45 of Set 8 | mbuguni
# Processing Record 46 of Set 8 | moroni
# Processing Record 47 of Set 8 | denpasar
# Processing Record 48 of Set 8 | srandakan
# Processing Record 49 of Set 8 | yumen
# Processing Record 50 of Set 8 | ambanja
# Processing Record 1 of Set 9 | phatthalung
# Processing Record 2 of Set 9 | ginir
# Processing Record 3 of Set 9 | tambacounda
# Processing Record 4 of Set 9 | jutai
# Processing Record 5 of Set 9 | brae
# Processing Record 6 of Set 9 | price
# Processing Record 7 of Set 9 | rio gallegos
# Processing Record 8 of Set 9 | zhenjiang
# Processing Record 9 of Set 9 | broome
# Processing Record 10 of Set 9 | tura
# Processing Record 11 of Set 9 | cabedelo
# Processing Record 12 of Set 9 | shimoda
# Processing Record 13 of Set 9 | saskylakh
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | ulladulla
# Processing Record 16 of Set 9 | igarka
# Processing Record 17 of Set 9 | mitu
# Processing Record 18 of Set 9 | erenhot
# Processing Record 19 of Set 9 | troitsko-pechorsk
# Processing Record 20 of Set 9 | kirakira
# Processing Record 21 of Set 9 | villa de reyes
# Processing Record 22 of Set 9 | agogo
# Processing Record 23 of Set 9 | tupik
# Processing Record 24 of Set 9 | urdoma
# Processing Record 25 of Set 9 | yerbogachen
# Processing Record 26 of Set 9 | beloha
# Processing Record 27 of Set 9 | kupang
# Processing Record 28 of Set 9 | olafsvik
# Processing Record 29 of Set 9 | tiznit
# Processing Record 30 of Set 9 | cordoba
# Processing Record 31 of Set 9 | xianyang
# Processing Record 32 of Set 9 | rabo de peixe
# Processing Record 33 of Set 9 | rio grande
# Processing Record 34 of Set 9 | maniitsoq
# Processing Record 35 of Set 9 | homer
# Processing Record 36 of Set 9 | melendugno
# Processing Record 37 of Set 9 | panjab
# Processing Record 38 of Set 9 | rome
# Processing Record 39 of Set 9 | portland
# Processing Record 40 of Set 9 | banyo
# Processing Record 41 of Set 9 | arlit
# Processing Record 42 of Set 9 | huanan
# Processing Record 43 of Set 9 | eseka
# Processing Record 44 of Set 9 | lazarev
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | kurilsk
# Processing Record 47 of Set 9 | cam ranh
# Processing Record 48 of Set 9 | morro bay
# Processing Record 49 of Set 9 | surab
# Processing Record 50 of Set 9 | port blair
# Processing Record 1 of Set 10 | ayutla
# Processing Record 2 of Set 10 | cheb
# Processing Record 3 of Set 10 | dipkarpaz
# City not found. Skipping...
# Processing Record 4 of Set 10 | poya
# Processing Record 5 of Set 10 | kudahuvadhoo
# Processing Record 6 of Set 10 | whittlesea
# Processing Record 7 of Set 10 | kuusamo
# Processing Record 8 of Set 10 | vilyuysk
# Processing Record 9 of Set 10 | cim
# Processing Record 10 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 10 | wenling
# Processing Record 12 of Set 10 | cachoeira do sul
# Processing Record 13 of Set 10 | dargaville
# Processing Record 14 of Set 10 | asau
# Processing Record 15 of Set 10 | machinga
# Processing Record 16 of Set 10 | tobol
# Processing Record 17 of Set 10 | sabang
# Processing Record 18 of Set 10 | margate
# Processing Record 19 of Set 10 | mujiayingzi
# Processing Record 20 of Set 10 | nemuro
# Processing Record 21 of Set 10 | golden
# Processing Record 22 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | syracuse
# Processing Record 25 of Set 10 | cody
# Processing Record 26 of Set 10 | sarakhs
# Processing Record 27 of Set 10 | kodinsk
# Processing Record 28 of Set 10 | kavaratti
# Processing Record 29 of Set 10 | hare bay
# Processing Record 30 of Set 10 | itarema
# Processing Record 31 of Set 10 | bethanien
# Processing Record 32 of Set 10 | kushmurun
# Processing Record 33 of Set 10 | oga
# Processing Record 34 of Set 10 | feldru
# Processing Record 35 of Set 10 | benghazi
# Processing Record 36 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 10 | canmore
# Processing Record 38 of Set 10 | tomatlan
# Processing Record 39 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 40 of Set 10 | kailua
# Processing Record 41 of Set 10 | kouango
# Processing Record 42 of Set 10 | santa lucia
# Processing Record 43 of Set 10 | gornozavodsk
# Processing Record 44 of Set 10 | rietavas
# Processing Record 45 of Set 10 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 46 of Set 10 | dwarka
# Processing Record 47 of Set 10 | ossora
# Processing Record 48 of Set 10 | half moon bay
# Processing Record 49 of Set 10 | hirara
# Processing Record 50 of Set 10 | kalmunai
# Processing Record 1 of Set 11 | burdeos
# Processing Record 2 of Set 11 | lamu
# Processing Record 3 of Set 11 | rorvik
# Processing Record 4 of Set 11 | vitim
# Processing Record 5 of Set 11 | tavda
# Processing Record 6 of Set 11 | paciran
# Processing Record 7 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 8 of Set 11 | rincon
# Processing Record 9 of Set 11 | coevorden
# Processing Record 10 of Set 11 | juneau
# Processing Record 11 of Set 11 | faanui
# Processing Record 12 of Set 11 | san angelo
# Processing Record 13 of Set 11 | sangar
# Processing Record 14 of Set 11 | burkburnett
# Processing Record 15 of Set 11 | soure
# Processing Record 16 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 11 | paraopeba
# Processing Record 18 of Set 11 | seminole
# Processing Record 19 of Set 11 | north vanlaiphai
# Processing Record 20 of Set 11 | miraflores
# Processing Record 21 of Set 11 | gorontalo
# Processing Record 22 of Set 11 | egvekinot
# Processing Record 23 of Set 11 | birao
# Processing Record 24 of Set 11 | kapoeta
# Processing Record 25 of Set 11 | abu dhabi
# Processing Record 26 of Set 11 | pinhao
# Processing Record 27 of Set 11 | guarapari
# Processing Record 28 of Set 11 | san jose
# Processing Record 29 of Set 11 | arauca
# Processing Record 30 of Set 11 | opuwo
# Processing Record 31 of Set 11 | xining
# Processing Record 32 of Set 11 | iquitos
# Processing Record 33 of Set 11 | marsh harbour
# Processing Record 34 of Set 11 | qasigiannguit
# Processing Record 35 of Set 11 | novyy urengoy
# Processing Record 36 of Set 11 | seoul
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | bastia
# Processing Record 39 of Set 11 | chapada dos guimaraes
# Processing Record 40 of Set 11 | cockburn town
# Processing Record 41 of Set 11 | juan lacaze
# Processing Record 42 of Set 11 | azimur
# City not found. Skipping...
# Processing Record 43 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 11 | zarubino
# Processing Record 45 of Set 11 | sao gabriel da cachoeira
# Processing Record 46 of Set 11 | zambezi
# Processing Record 47 of Set 11 | yermakovskoye
# Processing Record 48 of Set 11 | yate
# Processing Record 49 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 50 of Set 11 | abu samrah
# Processing Record 1 of Set 12 | esna
# Processing Record 2 of Set 12 | sunland park
# Processing Record 3 of Set 12 | kharovsk
# Processing Record 4 of Set 12 | flin flon
# Processing Record 5 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 12 | murgab
# Processing Record 7 of Set 12 | nanortalik
# Processing Record 8 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 12 | takab
# Processing Record 10 of Set 12 | kaeo
# Processing Record 11 of Set 12 | tuy hoa
# Processing Record 12 of Set 12 | wanning
# Processing Record 13 of Set 12 | aranos
# Processing Record 14 of Set 12 | srednekolymsk
# Processing Record 15 of Set 12 | rapid valley
# Processing Record 16 of Set 12 | saint anthony
# Processing Record 17 of Set 12 | yamada
# Processing Record 18 of Set 12 | akhmim
# Processing Record 19 of Set 12 | norrtalje
# Processing Record 20 of Set 12 | pisco
# Processing Record 21 of Set 12 | leshukonskoye
# Processing Record 22 of Set 12 | bristol
# Processing Record 23 of Set 12 | loa janan
# Processing Record 24 of Set 12 | elko
# Processing Record 25 of Set 12 | turochak
# Processing Record 26 of Set 12 | samarai
# Processing Record 27 of Set 12 | kaabong
# Processing Record 28 of Set 12 | batemans bay
# Processing Record 29 of Set 12 | antalaha
# Processing Record 30 of Set 12 | gigmoto
# Processing Record 31 of Set 12 | kazerun
# Processing Record 32 of Set 12 | farafangana
# Processing Record 33 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 34 of Set 12 | uvira
# Processing Record 35 of Set 12 | roald
# Processing Record 36 of Set 12 | letterkenny
# Processing Record 37 of Set 12 | lorengau
# Processing Record 38 of Set 12 | zalantun
# Processing Record 39 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 12 | ballina
# Processing Record 41 of Set 12 | tigil
# Processing Record 42 of Set 12 | wuwei
# Processing Record 43 of Set 12 | baruun-urt
# Processing Record 44 of Set 12 | aguadilla
# Processing Record 45 of Set 12 | pasighat
# Processing Record 46 of Set 12 | aykhal
# Processing Record 47 of Set 12 | nalvo
# Processing Record 48 of Set 12 | pato branco
# Processing Record 49 of Set 12 | port shepstone
# Processing Record 50 of Set 12 | minna
# Processing Record 1 of Set 13 | kaura namoda
# Processing Record 2 of Set 13 | emerald
# Processing Record 3 of Set 13 | ekhabi
# Processing Record 4 of Set 13 | baracoa
# Processing Record 5 of Set 13 | nezhinskiy
# Processing Record 6 of Set 13 | tambo
# Processing Record 7 of Set 13 | chapais
# Processing Record 8 of Set 13 | harindanga
# Processing Record 9 of Set 13 | viedma
# Processing Record 10 of Set 13 | ormara
# Processing Record 11 of Set 13 | lady lake
# Processing Record 12 of Set 13 | anju
# Processing Record 13 of Set 13 | mecca
# Processing Record 14 of Set 13 | ust-ilimsk
# Processing Record 15 of Set 13 | zadonsk
# Processing Record 16 of Set 13 | sorland
# Processing Record 17 of Set 13 | waipawa
# Processing Record 18 of Set 13 | conceicao do araguaia
# Processing Record 19 of Set 13 | diban
# Processing Record 20 of Set 13 | manokwari
# Processing Record 21 of Set 13 | bani
# Processing Record 22 of Set 13 | vostok
# Processing Record 23 of Set 13 | mayo
# Processing Record 24 of Set 13 | beringovskiy
# Processing Record 25 of Set 13 | ukiah
# Processing Record 26 of Set 13 | mawlaik
# Processing Record 27 of Set 13 | nioro
# Processing Record 28 of Set 13 | teya
# Processing Record 29 of Set 13 | dorado
# Processing Record 30 of Set 13 | gazli
# Processing Record 31 of Set 13 | san cristobal
# Processing Record 32 of Set 13 | blagoyevo
# Processing Record 33 of Set 13 | laredo
# Processing Record 34 of Set 13 | ostersund
# Processing Record 35 of Set 13 | lompoc
# Processing Record 36 of Set 13 | fomboni
# Processing Record 37 of Set 13 | fort nelson
# Processing Record 38 of Set 13 | canoinhas
# Processing Record 39 of Set 13 | bonthe
# Processing Record 40 of Set 13 | paramonga
# Processing Record 41 of Set 13 | vestmannaeyjar
# Processing Record 42 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 13 | cururupu
# Processing Record 44 of Set 13 | angelholm
# City not found. Skipping...
# Processing Record 45 of Set 13 | omboue
# Processing Record 46 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 13 | daru
# Processing Record 48 of Set 13 | laizhou
# Processing Record 49 of Set 13 | kerchevskiy
# Processing Record 50 of Set 13 | irbil
# Processing Record 1 of Set 14 | batagay-alyta
# Processing Record 2 of Set 14 | asfi
# Processing Record 3 of Set 14 | temirgoyevskaya
# Processing Record 4 of Set 14 | lopsmarka
# Processing Record 5 of Set 14 | bida
# Processing Record 6 of Set 14 | morant bay
# Processing Record 7 of Set 14 | vila velha
# Processing Record 8 of Set 14 | methoni
# Processing Record 9 of Set 14 | gunjur
# Processing Record 10 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 14 | ust-tsilma
# Processing Record 12 of Set 14 | kaifeng
# Processing Record 13 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 14 | pueblo
# Processing Record 15 of Set 14 | tonder
# Processing Record 16 of Set 14 | punta cardon
# Processing Record 17 of Set 14 | namibe
# Processing Record 18 of Set 14 | abha
# Processing Record 19 of Set 14 | kopavogur
# Processing Record 20 of Set 14 | sao joao da barra
# Processing Record 21 of Set 14 | atbasar
# Processing Record 22 of Set 14 | agva
# City not found. Skipping...
# Processing Record 23 of Set 14 | hikari
# Processing Record 24 of Set 14 | fare
# Processing Record 25 of Set 14 | cortez
# Processing Record 26 of Set 14 | central point
# Processing Record 27 of Set 14 | santa luzia
# Processing Record 28 of Set 14 | tessalit
# Processing Record 29 of Set 14 | solnechnyy
# Processing Record 30 of Set 14 | turinskaya sloboda
# Processing Record 31 of Set 14 | yining
# Processing Record 32 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 33 of Set 14 | mandera
# Processing Record 34 of Set 14 | imeni poliny osipenko
# Processing Record 35 of Set 14 | ganzhou
# Processing Record 36 of Set 14 | fort smith
# Processing Record 37 of Set 14 | port-gentil
# Processing Record 38 of Set 14 | puerto quijarro
# Processing Record 39 of Set 14 | sinnamary
# Processing Record 40 of Set 14 | meadow lake
# Processing Record 41 of Set 14 | nebolchi
# Processing Record 42 of Set 14 | kiunga
# Processing Record 43 of Set 14 | aasiaat
# Processing Record 44 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 14 | ibara
# Processing Record 46 of Set 14 | lugovskiy
# City not found. Skipping...
# Processing Record 47 of Set 14 | noumea
# Processing Record 48 of Set 14 | mobara
# Processing Record 49 of Set 14 | onalaska
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | praia
# Processing Record 2 of Set 15 | samatau
# City not found. Skipping...
# Processing Record 3 of Set 15 | algiers
# Processing Record 4 of Set 15 | pundaguitan
# Processing Record 5 of Set 15 | port augusta
# Processing Record 6 of Set 15 | avera
# Processing Record 7 of Set 15 | mumbwa
# Processing Record 8 of Set 15 | nelson bay
# Processing Record 9 of Set 15 | akdepe
# Processing Record 10 of Set 15 | lixourion
# Processing Record 11 of Set 15 | nara
# Processing Record 12 of Set 15 | iranshahr
# Processing Record 13 of Set 15 | la ronge
# Processing Record 14 of Set 15 | amberley
# Processing Record 15 of Set 15 | sakakah
# Processing Record 16 of Set 15 | college
# Processing Record 17 of Set 15 | avallon
# Processing Record 18 of Set 15 | garner
# Processing Record 19 of Set 15 | liuzhou
# Processing Record 20 of Set 15 | saint-joseph
# Processing Record 21 of Set 15 | hashtrud
# Processing Record 22 of Set 15 | bhimunipatnam
# Processing Record 23 of Set 15 | vondrozo
# Processing Record 24 of Set 15 | cedral
# Processing Record 25 of Set 15 | narsaq
# Processing Record 26 of Set 15 | hue
# Processing Record 27 of Set 15 | yazman
# Processing Record 28 of Set 15 | boali
# Processing Record 29 of Set 15 | sao desiderio
# Processing Record 30 of Set 15 | mbale
# Processing Record 31 of Set 15 | lasa
# Processing Record 32 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 15 | verkhoyansk
# Processing Record 34 of Set 15 | vanimo
# Processing Record 35 of Set 15 | vokhtoga
# Processing Record 36 of Set 15 | buala
# Processing Record 37 of Set 15 | mizdah
# Processing Record 38 of Set 15 | aksarka
# Processing Record 39 of Set 15 | gardan diwal
# City not found. Skipping...
# Processing Record 40 of Set 15 | santa quiteria
# Processing Record 41 of Set 15 | maneadero
# Processing Record 42 of Set 15 | grand gaube
# Processing Record 43 of Set 15 | preobrazheniye
# Processing Record 44 of Set 15 | linhares
# Processing Record 45 of Set 15 | sri aman
# Processing Record 46 of Set 15 | yemelyanovo
# Processing Record 47 of Set 15 | trinidad
# Processing Record 48 of Set 15 | oudtshoorn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 683

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia -54.8000  -68.3000     47.86        57          75
# 1  Saint-Philippe -21.3585   55.7679     71.19        81          43
# 2   Mar Del Plata -38.0023  -57.5575     53.62        79           0
# 3          Atuona  -9.8000 -139.0333     76.68        72          16
# 4            Liku  -0.7275  119.8922     73.24        92          73
# 5        Mbandaka   0.0487   18.2603     70.34        97         100
# 6         Qaanaaq  77.4840  -69.3632     16.18        72         100
# 7       Tilichiki  60.4667  166.1000     33.37        73         100
# 8     Port Alfred -33.5906   26.8910     59.18        89          91
# 9     Bandarbeyla   9.4942   50.8122     77.49        80          92
#
#    Wind Speed Country Current description
# 0        2.30      AR       broken clouds
# 1       12.08      RE    scattered clouds
# 2       11.50      AR           clear sky
# 3       18.37      PF          few clouds
# 4        2.13      ID       broken clouds
# 5        2.66      CD     overcast clouds
# 6        6.38      GL     overcast clouds
# 7        5.97      RU     overcast clouds
# 8        1.99      ZA     overcast clouds
# 9       19.24      SO     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     47.86        57          75
# 1  Saint-Philippe      RE -21.3585   55.7679     71.19        81          43
# 2   Mar Del Plata      AR -38.0023  -57.5575     53.62        79           0
# 3          Atuona      PF  -9.8000 -139.0333     76.68        72          16
# 4            Liku      ID  -0.7275  119.8922     73.24        92          73
# 5        Mbandaka      CD   0.0487   18.2603     70.34        97         100
# 6         Qaanaaq      GL  77.4840  -69.3632     16.18        72         100
# 7       Tilichiki      RU  60.4667  166.1000     33.37        73         100
# 8     Port Alfred      ZA -33.5906   26.8910     59.18        89          91
# 9     Bandarbeyla      SO   9.4942   50.8122     77.49        80          92
#
#    Wind Speed Current description
# 0        2.30       broken clouds
# 1       12.08    scattered clouds
# 2       11.50           clear sky
# 3       18.37          few clouds
# 4        2.13       broken clouds
# 5        2.66     overcast clouds
# 6        6.38     overcast clouds
# 7        5.97     overcast clouds
# 8        1.99     overcast clouds
# 9       19.24     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City ID")
